# %%
import numpy as np
import matplotlib.pyplot as plt
import funciones as f


entradas_1 = np.linspace(-10, 10, 200)
entradas_2 = np.linspace(-5, 5, 100)
plt.plot(entradas_1, f.elevar_al_cuadrado(entradas_1),label='$f(x)$')
plt.figure()
plt.plot(entradas_2, f.product_seno_coseno(entradas_2,entradas_2),label='$g(x,y)$')
